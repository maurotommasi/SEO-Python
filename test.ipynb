# %%
from SEO import SEO
SEO = SEO()
baseUrl = "https://edition.cnn.com/"
onpage_seo_results, broken_links = SEO.generate_seo_report(baseUrl, True)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\development\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\development\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# SEO Audit Report for https://edition.cnn.com/:
# On-Page SEO Analysis:                                            Meta Tags  \
# 0  {'viewport': 'width=device-width,initial-scale...
#
#                                             Headings  \
# 0  {'h1': [], 'h2': ['Two American hostages relea...
#
#                                                Links  \
# 0  [https://edition.cnn.com, https://edition.cnn....
#
#                                         Text Content  \
# 0  Breaking News, Latest News and Videos | CNNCNN...
#
#                                               Images  \
# 0  [https://media.cnn.com/api/v1/images/stellar/p...
#
# ...

# %%
# Achieve Data

onpage_seo_results['Images'][0]
# Out:
# ['https://media.cnn.com/api/v1/images/stellar/prod/231013163712-judith-and-natali-raanan.jpg?c=16x9&q=h_720,w_1280,c_fill',
#  'https://media.cnn.com/api/v1/images/stellar/prod/231020140843-02-jim-jordan-house-speaker-vote-102023.jpg?c=16x9&q=h_720,w_1280,c_fill',
#  'https://media.cnn.com/api/v1/images/stellar/prod/231020082717-01-chesebro-in-court-101023.jpg?c=16x9&q=h_720,w_1280,c_fill',
#  'https://media.cnn.com/api/v1/images/stellar/prod/cnn-fast-master-1920x1080-a.png?c=16x9&q=w_850,c_fill',
#  'https://media.cnn.com/api/v1/images/stellar/prod/231020120325-01-christine-sinclair-file.jpg?c=16x9&q=h_438,w_780,c_fill',
#  'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-1356380176.jpg?c=16x9&q=h_438,w_780,c_fill',
#  'https://media.cnn.com/api/v1/images/stellar/prod/230821103549-04-hydra-greece-no-cars-scenic.jpg?c=16x9&q=h_438,w_780,c_fill',
#  'https://media.cnn.com/api/v1/images/stellar/prod/liao-2019-bed-wrestling-3210.jpg?c=16x9&q=h_438,w_780,c_fill',
# ...

# %%
# Achieve Data

onpage_seo_results['Keywords'][0]
# Out:
# ['width',
#  'device',
#  'width',
#  'initial',
#  'scale',
#  '1',
#  'shrink',
#  'to',
#  'fit',
#  'no',
#  'Breaking',
#  'News',
#  'Latest',
#  'News',
#  'and',
#  'Videos',
#  'CNN',
#  'View',
#  'the',
#  'latest',
#  'news',
#  'and',
#  'breaking',
#  'news',
#  'today',
#  'for',
#  'U',
#  'S',
#  'world',
#  'weather',
#  'entertainment',
#  'politics',
#  'and',
#  'health',
#  'at',
#  'CNN',
#  'com',
#  'View',
#  'the',
#  'latest',
#  'news',
#  'and',
#  'breaking',
#  'news',
#  'today',
#  'for',
#  'U',
#  'S',
#  'world',
#  'weather',
#  'entertainment',
#  'politics',
#  'and',
#  'health',
#  'at',
#  'CNN',
#  'com',
#  'View',
#  'the',
#  'latest',
#  'news',
#  'and',
#  'breaking',
#  'news',
#  'today',
#  'for',
#  'U',
#  'S',
#  'world',
#  'weather',
#  'entertainment',
#  'politics',
#  'and',
#  'health',
#  'at',
#  'CNN',
#  'com',
#  'landing_homepage',
#  'section',
#  'homepage',
#  'cnn',
#  'summary_large_image',
#  'cnn',
#  'news',
# ...

# %%
# Nested Analysis

nestedSEO = {}

for nestedLink in onpage_seo_results["Links"][0]:
    if baseUrl in nestedLink:
        nestedSEO[nestedLink], _ = SEO.generate_seo_report(nestedLink, True)
